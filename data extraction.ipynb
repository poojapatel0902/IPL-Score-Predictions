# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('ipl'):
    filenames.append(os.path.join('ipl',file))

# %%
filenames[0:5]
# Out:
# ['ipl\\1082591.yaml',
#  'ipl\\1082592.yaml',
#  'ipl\\1082593.yaml',
#  'ipl\\1082594.yaml',
#  'ipl\\1082595.yaml']

# %%
from yaml import safe_load, safe_load_all
import json
def load_records_from_text(text: str):
    text = (text or "").strip()
    if not text:
        return []

    # Try JSON Lines (NDJSON)
    try:
        lines = [json.loads(line) for line in text.splitlines() if line.strip()]
        if lines and all(isinstance(x, dict) for x in lines):
            return lines
    except Exception:
        pass

    # Try JSON array/object
    try:
        obj = json.loads(text)
        if isinstance(obj, list):
            return obj
        if isinstance(obj, dict):
            return [obj]
    except Exception:
        pass

    # Try YAML (single/multi-doc)
    try:
        docs = list(safe_load_all(text))  # works for 1 or many docs
        out = []
        for d in docs:
            if d is None:
                continue
            if isinstance(d, list):
                out.extend(d)
            elif isinstance(d, dict):
                out.append(d)
        if out:
            return out
    except Exception:
        pass

    return []

dfs = []
counter = 0

for file in tqdm(filenames):
    with open(file, 'r', encoding='utf-8') as f:
        text = f.read()
    records = load_records_from_text(text)
    if not records:
        # Agar file empty ya unparsable ho, skip kar do
        continue

    df = pd.json_normalize(records)  # optionally: sep='.' for nested keys
    df['match_id'] = counter
    dfs.append(df)
    counter += 1

final_df = pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()
# Out:
# 100%|██████████| 1170/1170 [04:42<00:00,  4.13it/s]

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...               0.91
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...               0.91
# 4     [{'1st innings': {'team': 'Royal Challengers B...               0.91
# ...                                                 ...                ...
# 1164  [{'1st innings': {'team': 'Delhi Daredevils', ...               0.91
# 1165  [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 1166  [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
# 1167  [{'1st innings': {'team': 'Gujarat Lions', 'de...               0.91
# 1168  [{'1st innings': {'team': 'Sunrisers Hyderabad...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-04-06              1                    6  Hyderabad
# 1      2017-04-07              1                    6       Pune
# 2      2017-04-07              2                    6     Rajkot
# 3      2017-04-08              1                    6     Indore
# 4      2017-04-08              2                    6  Bengaluru
# ...           ...            ...                  ...        ...
# 1164   2016-05-23              1                    6     Raipur
# 1165   2016-05-24              1                    6  Bangalore
# 1166   2016-05-25              1                    6      Delhi
# 1167   2016-05-28              1                    6      Delhi
# 1168   2016-05-30              1                    6  Bangalore
#
#      info.competition    info.dates info.gender info.match_type  ...  \
# 0                 IPL  [2017-04-05]        male             T20  ...
# 1                 IPL  [2017-04-06]        male             T20  ...
# 2                 IPL  [2017-04-07]        male             T20  ...
# 3                 IPL  [2017-04-08]        male             T20  ...
# 4                 IPL  [2017-04-08]        male             T20  ...
# ...               ...           ...         ...             ...  ...
# 1164              IPL  [2016-05-22]        male             T20  ...
# 1165              IPL  [2016-05-24]        male             T20  ...
# 1166              IPL  [2016-05-25]        male             T20  ...
# 1167              IPL  [2016-05-27]        male             T20  ...
# 1168              IPL  [2016-05-29]        male             T20  ...
#
#       info.registry.people.B Aparajith info.registry.people.GS Sandhu  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1164                               NaN                            NaN
# 1165                               NaN                            NaN
# 1166                               NaN                            NaN
# 1167                               NaN                            NaN
# 1168                               NaN                            NaN
#
#       info.players.Rising Pune Supergiants info.registry.people.P Sahu  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 1164                                   NaN                         NaN
# 1165                                   NaN                         NaN
# 1166                                   NaN                         NaN
# 1167                                   NaN                         NaN
# 1168                                   NaN                         NaN
#
#      info.registry.people.KJ Abbott info.registry.people.PSP Handscomb  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ...                             ...                                ...
# 1164                            NaN                                NaN
# 1165                            NaN                                NaN
# 1166                            NaN                                NaN
# 1167                            NaN                                NaN
# 1168                            NaN                                NaN
#
#      info.registry.people.SM Boland info.registry.people.UT Khawaja  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 1164                            NaN                             NaN
# 1165                            NaN                             NaN
# 1166                            NaN                             NaN
# 1167                            NaN                             NaN
# 1168                            NaN                             NaN
#
#      info.registry.people.F Behardien info.registry.people.ER Dwivedi
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 1164                              NaN                             NaN
# 1165                              NaN                        b274dbbd
# 1166                              NaN                             NaN
# 1167                              NaN                        b274dbbd
# 1168                              NaN                             NaN
#
# [1169 rows x 971 columns]

# %%
# 1. Define specific administrative columns to drop
cols_to_drop = [
    'meta.data_version', 
    'meta.created', 
    'meta.revision',
    'info.balls_per_over',
    'info.gender',
    'info.match_type',
    'info.competition'
]

# 2. Automatically find all 'registry' and 'players' columns (these are mostly NaN)
registry_cols = [col for col in final_df.columns if 'info.registry.people' in col]
player_list_cols = [col for col in final_df.columns if 'info.players' in col]

# 3. Combine and drop everything in one command
final_df.drop(columns=cols_to_drop + registry_cols + player_list_cols, inplace=True, errors='ignore')

# 4. Optional: View the clean columns remaining
print(final_df.columns)
# Out:
# Index(['innings', 'info.city', 'info.dates', 'info.outcome.by.runs',
#        'info.outcome.winner', 'info.overs', 'info.player_of_match',
#        'info.teams', 'info.toss.decision', 'info.toss.winner', 'info.umpires',
#        'info.venue', 'match_id', 'info.outcome.by.wickets',
#        'info.outcome.eliminator', 'info.outcome.result', 'info.outcome.method',
#        'info.neutral_venue'],
#       dtype='object')

# %%
final_df
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...  Hyderabad
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...       Pune
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...     Rajkot
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...     Indore
# 4     [{'1st innings': {'team': 'Royal Challengers B...  Bengaluru
# ...                                                 ...        ...
# 1164  [{'1st innings': {'team': 'Delhi Daredevils', ...     Raipur
# 1165  [{'1st innings': {'team': 'Gujarat Lions', 'de...  Bangalore
# 1166  [{'1st innings': {'team': 'Sunrisers Hyderabad...      Delhi
# 1167  [{'1st innings': {'team': 'Gujarat Lions', 'de...      Delhi
# 1168  [{'1st innings': {'team': 'Sunrisers Hyderabad...  Bangalore
#
#         info.dates  info.outcome.by.runs          info.outcome.winner  \
# 0     [2017-04-05]                  35.0          Sunrisers Hyderabad
# 1     [2017-04-06]                   NaN       Rising Pune Supergiant
# 2     [2017-04-07]                   NaN        Kolkata Knight Riders
# 3     [2017-04-08]                   NaN              Kings XI Punjab
# 4     [2017-04-08]                  15.0  Royal Challengers Bangalore
# ...            ...                   ...                          ...
# 1164  [2016-05-22]                   NaN  Royal Challengers Bangalore
# 1165  [2016-05-24]                   NaN  Royal Challengers Bangalore
# 1166  [2016-05-25]                  22.0          Sunrisers Hyderabad
# 1167  [2016-05-27]                   NaN          Sunrisers Hyderabad
# 1168  [2016-05-29]                   8.0          Sunrisers Hyderabad
#
#       info.overs info.player_of_match  \
# 0             20       [Yuvraj Singh]
# 1             20          [SPD Smith]
# 2             20            [CA Lynn]
# 3             20         [GJ Maxwell]
# 4             20          [KM Jadhav]
# ...          ...                  ...
# 1164          20            [V Kohli]
# 1165          20     [AB de Villiers]
# 1166          20       [MC Henriques]
# 1167          20          [DA Warner]
# 1168          20        [BCJ Cutting]
#
#                                              info.teams info.toss.decision  \
# 0     [Sunrisers Hyderabad, Royal Challengers Bangal...              field
# 1              [Rising Pune Supergiant, Mumbai Indians]              field
# 2                [Gujarat Lions, Kolkata Knight Riders]              field
# 3             [Kings XI Punjab, Rising Pune Supergiant]              field
# 4       [Royal Challengers Bangalore, Delhi Daredevils]                bat
# ...                                                 ...                ...
# 1164    [Delhi Daredevils, Royal Challengers Bangalore]              field
# 1165       [Gujarat Lions, Royal Challengers Bangalore]              field
# 1166       [Sunrisers Hyderabad, Kolkata Knight Riders]              field
# 1167               [Gujarat Lions, Sunrisers Hyderabad]              field
# 1168  [Royal Challengers Bangalore, Sunrisers Hydera...                bat
#
#                  info.toss.winner                     info.umpires  \
# 0     Royal Challengers Bangalore          [AY Dandekar, NJ Llong]
# 1          Rising Pune Supergiant         [A Nand Kishore, S Ravi]
# 2           Kolkata Knight Riders         [Nitin Menon, CK Nandan]
# 3                 Kings XI Punjab    [AK Chaudhary, C Shamshuddin]
# 4     Royal Challengers Bangalore              [S Ravi, VK Sharma]
# ...                           ...                              ...
# 1164  Royal Challengers Bangalore   [A Nand Kishore, BNJ Oxenford]
# 1165  Royal Challengers Bangalore  [AK Chaudhary, HDPK Dharmasena]
# 1166        Kolkata Knight Riders       [M Erasmus, C Shamshuddin]
# 1167          Sunrisers Hyderabad           [M Erasmus, CK Nandan]
# 1168          Sunrisers Hyderabad  [HDPK Dharmasena, BNJ Oxenford]
#
#                                             info.venue  match_id  \
# 0            Rajiv Gandhi International Stadium, Uppal         0
# 1              Maharashtra Cricket Association Stadium         1
# 2               Saurashtra Cricket Association Stadium         2
# 3                               Holkar Cricket Stadium         3
# 4                                M.Chinnaswamy Stadium         4
# ...                                                ...       ...
# 1164  Shaheed Veer Narayan Singh International Stadium      1164
# 1165                             M Chinnaswamy Stadium      1165
# 1166                                  Feroz Shah Kotla      1166
# 1167                                  Feroz Shah Kotla      1167
# 1168                             M Chinnaswamy Stadium      1168
#
#       info.outcome.by.wickets info.outcome.eliminator info.outcome.result  \
# 0                         NaN                     NaN                 NaN
# 1                         7.0                     NaN                 NaN
# 2                        10.0                     NaN                 NaN
# 3                         6.0                     NaN                 NaN
# 4                         NaN                     NaN                 NaN
# ...                       ...                     ...                 ...
# 1164                      6.0                     NaN                 NaN
# 1165                      4.0                     NaN                 NaN
# 1166                      NaN                     NaN                 NaN
# 1167                      4.0                     NaN                 NaN
# 1168                      NaN                     NaN                 NaN
#
#      info.outcome.method  info.neutral_venue
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# ...                  ...                 ...
# 1164                 NaN                 NaN
# 1165                 NaN                 NaN
# 1166                 NaN                 NaN
# 1167                 NaN                 NaN
# 1168                 NaN                 NaN
#
# [1169 rows x 18 columns]

# %%
final_df.drop(columns=[
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue'
], inplace=True, errors='ignore')

print(final_df.columns)
# Out:
# Index(['innings', 'info.city', 'info.dates', 'info.outcome.by.runs',
#        'info.outcome.winner', 'info.overs', 'info.player_of_match',
#        'info.teams', 'info.toss.decision', 'info.toss.winner', 'info.umpires',
#        'info.venue', 'match_id', 'info.outcome.by.wickets'],
#       dtype='object')

# %%
final_df
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...  Hyderabad
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...       Pune
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...     Rajkot
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...     Indore
# 4     [{'1st innings': {'team': 'Royal Challengers B...  Bengaluru
# ...                                                 ...        ...
# 1164  [{'1st innings': {'team': 'Delhi Daredevils', ...     Raipur
# 1165  [{'1st innings': {'team': 'Gujarat Lions', 'de...  Bangalore
# 1166  [{'1st innings': {'team': 'Sunrisers Hyderabad...      Delhi
# 1167  [{'1st innings': {'team': 'Gujarat Lions', 'de...      Delhi
# 1168  [{'1st innings': {'team': 'Sunrisers Hyderabad...  Bangalore
#
#         info.dates  info.outcome.by.runs          info.outcome.winner  \
# 0     [2017-04-05]                  35.0          Sunrisers Hyderabad
# 1     [2017-04-06]                   NaN       Rising Pune Supergiant
# 2     [2017-04-07]                   NaN        Kolkata Knight Riders
# 3     [2017-04-08]                   NaN              Kings XI Punjab
# 4     [2017-04-08]                  15.0  Royal Challengers Bangalore
# ...            ...                   ...                          ...
# 1164  [2016-05-22]                   NaN  Royal Challengers Bangalore
# 1165  [2016-05-24]                   NaN  Royal Challengers Bangalore
# 1166  [2016-05-25]                  22.0          Sunrisers Hyderabad
# 1167  [2016-05-27]                   NaN          Sunrisers Hyderabad
# 1168  [2016-05-29]                   8.0          Sunrisers Hyderabad
#
#       info.overs info.player_of_match  \
# 0             20       [Yuvraj Singh]
# 1             20          [SPD Smith]
# 2             20            [CA Lynn]
# 3             20         [GJ Maxwell]
# 4             20          [KM Jadhav]
# ...          ...                  ...
# 1164          20            [V Kohli]
# 1165          20     [AB de Villiers]
# 1166          20       [MC Henriques]
# 1167          20          [DA Warner]
# 1168          20        [BCJ Cutting]
#
#                                              info.teams info.toss.decision  \
# 0     [Sunrisers Hyderabad, Royal Challengers Bangal...              field
# 1              [Rising Pune Supergiant, Mumbai Indians]              field
# 2                [Gujarat Lions, Kolkata Knight Riders]              field
# 3             [Kings XI Punjab, Rising Pune Supergiant]              field
# 4       [Royal Challengers Bangalore, Delhi Daredevils]                bat
# ...                                                 ...                ...
# 1164    [Delhi Daredevils, Royal Challengers Bangalore]              field
# 1165       [Gujarat Lions, Royal Challengers Bangalore]              field
# 1166       [Sunrisers Hyderabad, Kolkata Knight Riders]              field
# 1167               [Gujarat Lions, Sunrisers Hyderabad]              field
# 1168  [Royal Challengers Bangalore, Sunrisers Hydera...                bat
#
#                  info.toss.winner                     info.umpires  \
# 0     Royal Challengers Bangalore          [AY Dandekar, NJ Llong]
# 1          Rising Pune Supergiant         [A Nand Kishore, S Ravi]
# 2           Kolkata Knight Riders         [Nitin Menon, CK Nandan]
# 3                 Kings XI Punjab    [AK Chaudhary, C Shamshuddin]
# 4     Royal Challengers Bangalore              [S Ravi, VK Sharma]
# ...                           ...                              ...
# 1164  Royal Challengers Bangalore   [A Nand Kishore, BNJ Oxenford]
# 1165  Royal Challengers Bangalore  [AK Chaudhary, HDPK Dharmasena]
# 1166        Kolkata Knight Riders       [M Erasmus, C Shamshuddin]
# 1167          Sunrisers Hyderabad           [M Erasmus, CK Nandan]
# 1168          Sunrisers Hyderabad  [HDPK Dharmasena, BNJ Oxenford]
#
#                                             info.venue  match_id  \
# 0            Rajiv Gandhi International Stadium, Uppal         0
# 1              Maharashtra Cricket Association Stadium         1
# 2               Saurashtra Cricket Association Stadium         2
# 3                               Holkar Cricket Stadium         3
# 4                                M.Chinnaswamy Stadium         4
# ...                                                ...       ...
# 1164  Shaheed Veer Narayan Singh International Stadium      1164
# 1165                             M Chinnaswamy Stadium      1165
# 1166                                  Feroz Shah Kotla      1166
# 1167                                  Feroz Shah Kotla      1167
# 1168                             M Chinnaswamy Stadium      1168
#
#       info.outcome.by.wickets
# 0                         NaN
# 1                         7.0
# 2                        10.0
# 3                         6.0
# 4                         NaN
# ...                       ...
# 1164                      6.0
# 1165                      4.0
# 1166                      NaN
# 1167                      4.0
# 1168                      NaN
#
# [1169 rows x 14 columns]

# %%
final_df['info.outcome.by.runs'].isnull().sum()
# Out:
# np.int64(638)

# %%
final_df['info.outcome.by.wickets'].isnull().sum()
# Out:
# np.int64(554)

# %%
final_df['info.outcome.by.runs'] = final_df['info.outcome.by.runs'].fillna(0)
final_df['info.outcome.by.wickets'] = final_df['info.outcome.by.wickets'].fillna(0)

# %%
final_df
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Sunrisers Hyderabad...  Hyderabad
# 1     [{'1st innings': {'team': 'Mumbai Indians', 'd...       Pune
# 2     [{'1st innings': {'team': 'Gujarat Lions', 'de...     Rajkot
# 3     [{'1st innings': {'team': 'Rising Pune Supergi...     Indore
# 4     [{'1st innings': {'team': 'Royal Challengers B...  Bengaluru
# ...                                                 ...        ...
# 1164  [{'1st innings': {'team': 'Delhi Daredevils', ...     Raipur
# 1165  [{'1st innings': {'team': 'Gujarat Lions', 'de...  Bangalore
# 1166  [{'1st innings': {'team': 'Sunrisers Hyderabad...      Delhi
# 1167  [{'1st innings': {'team': 'Gujarat Lions', 'de...      Delhi
# 1168  [{'1st innings': {'team': 'Sunrisers Hyderabad...  Bangalore
#
#         info.dates  info.outcome.by.runs          info.outcome.winner  \
# 0     [2017-04-05]                  35.0          Sunrisers Hyderabad
# 1     [2017-04-06]                   0.0       Rising Pune Supergiant
# 2     [2017-04-07]                   0.0        Kolkata Knight Riders
# 3     [2017-04-08]                   0.0              Kings XI Punjab
# 4     [2017-04-08]                  15.0  Royal Challengers Bangalore
# ...            ...                   ...                          ...
# 1164  [2016-05-22]                   0.0  Royal Challengers Bangalore
# 1165  [2016-05-24]                   0.0  Royal Challengers Bangalore
# 1166  [2016-05-25]                  22.0          Sunrisers Hyderabad
# 1167  [2016-05-27]                   0.0          Sunrisers Hyderabad
# 1168  [2016-05-29]                   8.0          Sunrisers Hyderabad
#
#       info.overs info.player_of_match  \
# 0             20       [Yuvraj Singh]
# 1             20          [SPD Smith]
# 2             20            [CA Lynn]
# 3             20         [GJ Maxwell]
# 4             20          [KM Jadhav]
# ...          ...                  ...
# 1164          20            [V Kohli]
# 1165          20     [AB de Villiers]
# 1166          20       [MC Henriques]
# 1167          20          [DA Warner]
# 1168          20        [BCJ Cutting]
#
#                                              info.teams info.toss.decision  \
# 0     [Sunrisers Hyderabad, Royal Challengers Bangal...              field
# 1              [Rising Pune Supergiant, Mumbai Indians]              field
# 2                [Gujarat Lions, Kolkata Knight Riders]              field
# 3             [Kings XI Punjab, Rising Pune Supergiant]              field
# 4       [Royal Challengers Bangalore, Delhi Daredevils]                bat
# ...                                                 ...                ...
# 1164    [Delhi Daredevils, Royal Challengers Bangalore]              field
# 1165       [Gujarat Lions, Royal Challengers Bangalore]              field
# 1166       [Sunrisers Hyderabad, Kolkata Knight Riders]              field
# 1167               [Gujarat Lions, Sunrisers Hyderabad]              field
# 1168  [Royal Challengers Bangalore, Sunrisers Hydera...                bat
#
#                  info.toss.winner                     info.umpires  \
# 0     Royal Challengers Bangalore          [AY Dandekar, NJ Llong]
# 1          Rising Pune Supergiant         [A Nand Kishore, S Ravi]
# 2           Kolkata Knight Riders         [Nitin Menon, CK Nandan]
# 3                 Kings XI Punjab    [AK Chaudhary, C Shamshuddin]
# 4     Royal Challengers Bangalore              [S Ravi, VK Sharma]
# ...                           ...                              ...
# 1164  Royal Challengers Bangalore   [A Nand Kishore, BNJ Oxenford]
# 1165  Royal Challengers Bangalore  [AK Chaudhary, HDPK Dharmasena]
# 1166        Kolkata Knight Riders       [M Erasmus, C Shamshuddin]
# 1167          Sunrisers Hyderabad           [M Erasmus, CK Nandan]
# 1168          Sunrisers Hyderabad  [HDPK Dharmasena, BNJ Oxenford]
#
#                                             info.venue  match_id  \
# 0            Rajiv Gandhi International Stadium, Uppal         0
# 1              Maharashtra Cricket Association Stadium         1
# 2               Saurashtra Cricket Association Stadium         2
# 3                               Holkar Cricket Stadium         3
# 4                                M.Chinnaswamy Stadium         4
# ...                                                ...       ...
# 1164  Shaheed Veer Narayan Singh International Stadium      1164
# 1165                             M Chinnaswamy Stadium      1165
# 1166                                  Feroz Shah Kotla      1166
# 1167                                  Feroz Shah Kotla      1167
# 1168                             M Chinnaswamy Stadium      1168
#
#       info.outcome.by.wickets
# 0                         0.0
# 1                         7.0
# 2                        10.0
# 3                         6.0
# 4                         0.0
# ...                       ...
# 1164                      6.0
# 1165                      4.0
# 1166                      0.0
# 1167                      4.0
# 1168                      0.0
#
# [1169 rows x 14 columns]

# %%
final_df.isnull().sum()
# Out:
# innings                     0
# info.city                  51
# info.dates                  0
# info.outcome.by.runs        0
# info.outcome.winner        23
# info.overs                  0
# info.player_of_match        8
# info.teams                  0
# info.toss.decision          0
# info.toss.winner            0
# info.umpires                0
# info.venue                  0
# match_id                    0
# info.outcome.by.wickets     0
# dtype: int64

# %%
final_df['info.city'] = final_df['info.city'].fillna('Unknown')
final_df['info.outcome.winner'] = final_df['info.outcome.winner'].fillna('No Result')
final_df['info.player_of_match'] = final_df['info.player_of_match'].fillna('No Player of match')
print(final_df.isnull().sum())
# Out:
# innings                    0
# info.city                  0
# info.dates                 0
# info.outcome.by.runs       0
# info.outcome.winner        0
# info.overs                 0
# info.player_of_match       0
# info.teams                 0
# info.toss.decision         0
# info.toss.winner           0
# info.umpires               0
# info.venue                 0
# match_id                   0
# info.outcome.by.wickets    0
# dtype: int64

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
# matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'DA Warner',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'DA Warner',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'DA Warner',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {0.4: {'batsman': 'DA Warner',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'DA Warner',
#    'bowler': 'TS Mills',
#    'extras': {'wides': 2},
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 2, 'total': 2}}},
#  {0.6: {'batsman': 'S Dhawan',
#    'bowler': 'TS Mills',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.7: {'batsman': 'S Dhawan',
#    'bowler': 'TS Mills',
#    'extras': {'legbyes': 1},
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {1.1: {'batsman': 'S Dhawan',
#    'bowler': 'A Choudhary',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.2: {'batsman': 'DA Warner',
#    'bowler': 'A Choudhary',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {1.3: {'batsman': 'DA Warner',
#    'bowler': 'A Choudhary',
#    'extras': {'noballs': 1},
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {1.4: {'batsman': 'DA Warner',
#    'bowler': 'A Choudhary',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {1.5: {'batsman': 'DA Warner',
#    'bowler': 'A Choudhary',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mandeep Singh'],
#     'kind': 'caught',
#     'player_out': 'DA Warner'}}},
#  {1.6: {'batsman': 'MC Henriques',
#    'bowler': 'A Choudhary',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.7: {'batsman': 'MC Henriques',
#    'bowler': 'A Choudhary',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {2.1: {'batsman': 'S Dhawan',
#    'bowler': 'TS Mills',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.2: {'batsman': 'MC Henriques',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.3: {'batsman': 'MC Henriques',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.4: {'batsman': 'MC Henriques',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {2.5: {'batsman': 'S Dhawan',
#    'bowler': 'TS Mills',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.6: {'batsman': 'MC Henriques',
#    'bowler': 'TS Mills',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.1: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.2: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.3: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.4: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.5: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.6: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.1: {'batsman': 'S Dhawan',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.2: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.3: {'batsman': 'S Dhawan',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.4: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {4.5: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {4.6: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.1: {'batsman': 'S Dhawan',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.2: {'batsman': 'S Dhawan',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.3: {'batsman': 'S Dhawan',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.4: {'batsman': 'S Dhawan',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.5: {'batsman': 'S Dhawan',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.6: {'batsman': 'S Dhawan',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.1: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.2: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.3: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.4: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.5: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.6: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.1: {'batsman': 'S Dhawan',
#    'bowler': 'TM Head',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.2: {'batsman': 'MC Henriques',
#    'bowler': 'TM Head',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.3: {'batsman': 'S Dhawan',
#    'bowler': 'TM Head',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.4: {'batsman': 'MC Henriques',
#    'bowler': 'TM Head',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {7.5: {'batsman': 'MC Henriques',
#    'bowler': 'TM Head',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.6: {'batsman': 'S Dhawan',
#    'bowler': 'TM Head',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.1: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {8.2: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.3: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.4: {'batsman': 'S Dhawan',
#    'bowler': 'YS Chahal',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.5: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {8.6: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {9.1: {'batsman': 'S Dhawan',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.2: {'batsman': 'S Dhawan',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.3: {'batsman': 'MC Henriques',
#    'bowler': 'A Choudhary',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.4: {'batsman': 'S Dhawan',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.5: {'batsman': 'MC Henriques',
#    'bowler': 'A Choudhary',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.6: {'batsman': 'S Dhawan',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.1: {'batsman': 'MC Henriques',
#    'bowler': 'STR Binny',
#    'non_striker': 'S Dhawan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.2: {'batsman': 'S Dhawan',
#    'bowler': 'STR Binny',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {10.3: {'batsman': 'S Dhawan',
#    'bowler': 'STR Binny',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Sachin Baby'],
#     'kind': 'caught',
#     'player_out': 'S Dhawan'}}},
#  {10.4: {'batsman': 'MC Henriques',
#    'bowler': 'STR Binny',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.5: {'batsman': 'Yuvraj Singh',
#    'bowler': 'STR Binny',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {10.6: {'batsman': 'Yuvraj Singh',
#    'bowler': 'STR Binny',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {11.1: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.2: {'batsman': 'Yuvraj Singh',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.3: {'batsman': 'Yuvraj Singh',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.4: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.5: {'batsman': 'Yuvraj Singh',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {11.6: {'batsman': 'Yuvraj Singh',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.1: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {12.2: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {12.3: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {12.4: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.5: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'extras': {'wides': 1},
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {12.6: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {12.7: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.1: {'batsman': 'Yuvraj Singh',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {13.2: {'batsman': 'Yuvraj Singh',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.3: {'batsman': 'MC Henriques',
#    'bowler': 'SR Watson',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.4: {'batsman': 'Yuvraj Singh',
#    'bowler': 'SR Watson',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.5: {'batsman': 'MC Henriques',
#    'bowler': 'SR Watson',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.6: {'batsman': 'MC Henriques',
#    'bowler': 'SR Watson',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.1: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {14.2: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.3: {'batsman': 'Yuvraj Singh',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {14.4: {'batsman': 'Yuvraj Singh',
#    'bowler': 'S Aravind',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.5: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {14.6: {'batsman': 'MC Henriques',
#    'bowler': 'S Aravind',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.1: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.2: {'batsman': 'MC Henriques',
#    'bowler': 'YS Chahal',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Sachin Baby'],
#     'kind': 'caught',
#     'player_out': 'MC Henriques'}}},
#  {15.3: {'batsman': 'Yuvraj Singh',
#    'bowler': 'YS Chahal',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.4: {'batsman': 'DJ Hooda',
#    'bowler': 'YS Chahal',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.5: {'batsman': 'Yuvraj Singh',
#    'bowler': 'YS Chahal',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.6: {'batsman': 'DJ Hooda',
#    'bowler': 'YS Chahal',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.1: {'batsman': 'DJ Hooda',
#    'bowler': 'TS Mills',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.2: {'batsman': 'Yuvraj Singh',
#    'bowler': 'TS Mills',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.3: {'batsman': 'Yuvraj Singh',
#    'bowler': 'TS Mills',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {16.4: {'batsman': 'Yuvraj Singh',
#    'bowler': 'TS Mills',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.5: {'batsman': 'DJ Hooda',
#    'bowler': 'TS Mills',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.6: {'batsman': 'DJ Hooda',
#    'bowler': 'TS Mills',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.1: {'batsman': 'DJ Hooda',
#    'bowler': 'A Choudhary',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {17.2: {'batsman': 'DJ Hooda',
#    'bowler': 'A Choudhary',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.3: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'extras': {'wides': 1},
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {17.4: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'extras': {'wides': 1},
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {17.5: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {17.6: {'batsman': 'Yuvraj Singh',
#    'bowler': 'A Choudhary',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.7: {'batsman': 'DJ Hooda',
#    'bowler': 'A Choudhary',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {17.8: {'batsman': 'DJ Hooda',
#    'bowler': 'A Choudhary',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.1: {'batsman': 'DJ Hooda',
#    'bowler': 'TS Mills',
#    'non_striker': 'Yuvraj Singh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.2: {'batsman': 'Yuvraj Singh',
#    'bowler': 'TS Mills',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {18.3: {'batsman': 'Yuvraj Singh',
#    'bowler': 'TS Mills',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {18.4: {'batsman': 'Yuvraj Singh',
#    'bowler': 'TS Mills',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'Yuvraj Singh'}}},
#  {18.5: {'batsman': 'BCJ Cutting',
#    'bowler': 'TS Mills',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.6: {'batsman': 'DJ Hooda',
#    'bowler': 'TS Mills',
#    'non_striker': 'BCJ Cutting',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.1: {'batsman': 'BCJ Cutting',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.2: {'batsman': 'DJ Hooda',
#    'bowler': 'SR Watson',
#    'non_striker': 'BCJ Cutting',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.3: {'batsman': 'BCJ Cutting',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {19.4: {'batsman': 'BCJ Cutting',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {19.5: {'batsman': 'BCJ Cutting',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.6: {'batsman': 'BCJ Cutting',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Hooda',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}]

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)

# %%
delivery_df
# Out:
#         match_id                                              teams  \
# 0              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 1              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 2              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 3              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 4              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# ...          ...                                                ...
# 142540      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142541      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142542      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142543      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142544      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
#
#                batting_team  ball      batsman     bowler  runs  \
# 0       Sunrisers Hyderabad   0.1    DA Warner   TS Mills     0
# 1       Sunrisers Hyderabad   0.2    DA Warner   TS Mills     0
# 2       Sunrisers Hyderabad   0.3    DA Warner   TS Mills     4
# 3       Sunrisers Hyderabad   0.4    DA Warner   TS Mills     0
# 4       Sunrisers Hyderabad   0.5    DA Warner   TS Mills     2
# ...                     ...   ...          ...        ...   ...
# 142540  Sunrisers Hyderabad  19.2  BCJ Cutting  SR Watson     6
# 142541  Sunrisers Hyderabad  19.3  BCJ Cutting  SR Watson     6
# 142542  Sunrisers Hyderabad  19.4  BCJ Cutting  SR Watson     1
# 142543  Sunrisers Hyderabad  19.5      B Kumar  SR Watson     1
# 142544  Sunrisers Hyderabad  19.6  BCJ Cutting  SR Watson     6
#
#        player_dismissed       city                                      venue
# 0                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 3                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 4                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# ...                 ...        ...                                        ...
# 142540                0  Bangalore                      M Chinnaswamy Stadium
# 142541                0  Bangalore                      M Chinnaswamy Stadium
# 142542                0  Bangalore                      M Chinnaswamy Stadium
# 142543                0  Bangalore                      M Chinnaswamy Stadium
# 142544                0  Bangalore                      M Chinnaswamy Stadium
#
# [142545 rows x 10 columns]

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#         match_id                                              teams  \
# 0              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 1              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 2              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 3              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# 4              2  [Sunrisers Hyderabad, Royal Challengers Bangal...
# ...          ...                                                ...
# 142540      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142541      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142542      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142543      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
# 142544      1170  [Royal Challengers Bangalore, Sunrisers Hydera...
#
#                batting_team  ball      batsman     bowler  runs  \
# 0       Sunrisers Hyderabad   0.1    DA Warner   TS Mills     0
# 1       Sunrisers Hyderabad   0.2    DA Warner   TS Mills     0
# 2       Sunrisers Hyderabad   0.3    DA Warner   TS Mills     4
# 3       Sunrisers Hyderabad   0.4    DA Warner   TS Mills     0
# 4       Sunrisers Hyderabad   0.5    DA Warner   TS Mills     2
# ...                     ...   ...          ...        ...   ...
# 142540  Sunrisers Hyderabad  19.2  BCJ Cutting  SR Watson     6
# 142541  Sunrisers Hyderabad  19.3  BCJ Cutting  SR Watson     6
# 142542  Sunrisers Hyderabad  19.4  BCJ Cutting  SR Watson     1
# 142543  Sunrisers Hyderabad  19.5      B Kumar  SR Watson     1
# 142544  Sunrisers Hyderabad  19.6  BCJ Cutting  SR Watson     6
#
#        player_dismissed       city                                      venue  \
# 0                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 3                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 4                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# ...                 ...        ...                                        ...
# 142540                0  Bangalore                      M Chinnaswamy Stadium
# 142541                0  Bangalore                      M Chinnaswamy Stadium
# 142542                0  Bangalore                      M Chinnaswamy Stadium
# 142543                0  Bangalore                      M Chinnaswamy Stadium
# 142544                0  Bangalore                      M Chinnaswamy Stadium
#
#                        bowling_team
# 0       Royal Challengers Bangalore
# 1       Royal Challengers Bangalore
# 2       Royal Challengers Bangalore
# 3       Royal Challengers Bangalore
# 4       Royal Challengers Bangalore
# ...                             ...
# 142540  Royal Challengers Bangalore
# 142541  Royal Challengers Bangalore
# 142542  Royal Challengers Bangalore
# 142543  Royal Challengers Bangalore
# 142544  Royal Challengers Bangalore
#
# [142545 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#         match_id         batting_team  ball      batsman     bowler  runs  \
# 0              2  Sunrisers Hyderabad   0.1    DA Warner   TS Mills     0
# 1              2  Sunrisers Hyderabad   0.2    DA Warner   TS Mills     0
# 2              2  Sunrisers Hyderabad   0.3    DA Warner   TS Mills     4
# 3              2  Sunrisers Hyderabad   0.4    DA Warner   TS Mills     0
# 4              2  Sunrisers Hyderabad   0.5    DA Warner   TS Mills     2
# ...          ...                  ...   ...          ...        ...   ...
# 142540      1170  Sunrisers Hyderabad  19.2  BCJ Cutting  SR Watson     6
# 142541      1170  Sunrisers Hyderabad  19.3  BCJ Cutting  SR Watson     6
# 142542      1170  Sunrisers Hyderabad  19.4  BCJ Cutting  SR Watson     1
# 142543      1170  Sunrisers Hyderabad  19.5      B Kumar  SR Watson     1
# 142544      1170  Sunrisers Hyderabad  19.6  BCJ Cutting  SR Watson     6
#
#        player_dismissed       city                                      venue  \
# 0                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 3                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 4                     0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# ...                 ...        ...                                        ...
# 142540                0  Bangalore                      M Chinnaswamy Stadium
# 142541                0  Bangalore                      M Chinnaswamy Stadium
# 142542                0  Bangalore                      M Chinnaswamy Stadium
# 142543                0  Bangalore                      M Chinnaswamy Stadium
# 142544                0  Bangalore                      M Chinnaswamy Stadium
#
#                        bowling_team
# 0       Royal Challengers Bangalore
# 1       Royal Challengers Bangalore
# 2       Royal Challengers Bangalore
# 3       Royal Challengers Bangalore
# 4       Royal Challengers Bangalore
# ...                             ...
# 142540  Royal Challengers Bangalore
# 142541  Royal Challengers Bangalore
# 142542  Royal Challengers Bangalore
# 142543  Royal Challengers Bangalore
# 142544  Royal Challengers Bangalore
#
# [142545 rows x 10 columns]

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Delhi Capitals',
#        'Punjab Kings', 'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %%
team_mapping = {
    'Delhi Daredevils': 'Delhi Capitals',
    'Kings XI Punjab': 'Punjab Kings',
    'Royal Challengers Bangalore': 'Royal Challengers Bengaluru',
    'Deccan Chargers': 'Sunrisers Hyderabad'
}
delivery_df['batting_team'] = delivery_df['batting_team'].replace(team_mapping)
print("Updated Team List:")
print(delivery_df['batting_team'].unique())
# Out:
# Updated Team List:
# ['Sunrisers Hyderabad' 'Mumbai Indians' 'Gujarat Lions'
#  'Rising Pune Supergiant' 'Royal Challengers Bengaluru'
#  'Kolkata Knight Riders' 'Delhi Capitals' 'Punjab Kings'
#  'Rajasthan Royals' 'Chennai Super Kings' 'Lucknow Super Giants'
#  'Gujarat Titans' 'Kochi Tuskers Kerala' 'Pune Warriors'
#  'Rising Pune Supergiants']

# %%
teams=[
    'Sunrisers Hyderabad',
    'Mumbai Indians', 
    'Royal Challengers Bengaluru',
    'Kolkata Knight Riders', 
    'Delhi Capitals',
    'Punjab Kings',
    'Rajasthan Royals', 
    'Chennai Super Kings', 
    'Lucknow Super Giants',
    'Gujarat Titans'  
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id           batting_team  ball       batsman      bowler  runs  \
# 741            8  Kolkata Knight Riders   0.1     G Gambhir  SL Malinga     1
# 742            8  Kolkata Knight Riders   0.2       CA Lynn  SL Malinga     1
# 743            8  Kolkata Knight Riders   0.3       CA Lynn  SL Malinga     1
# 744            8  Kolkata Knight Riders   0.4     G Gambhir  SL Malinga     0
# 745            8  Kolkata Knight Riders   0.5     G Gambhir  SL Malinga     1
# ...          ...                    ...   ...           ...         ...   ...
# 142289      1168    Sunrisers Hyderabad  19.2  Bipul Sharma    M Morkel     0
# 142290      1168    Sunrisers Hyderabad  19.3  Bipul Sharma    M Morkel     6
# 142291      1168    Sunrisers Hyderabad  19.4  Bipul Sharma    M Morkel     1
# 142292      1168    Sunrisers Hyderabad  19.5       B Kumar    M Morkel     0
# 142293      1168    Sunrisers Hyderabad  19.6  Bipul Sharma    M Morkel     1
#
#        player_dismissed    city             venue           bowling_team
# 741                   0  Mumbai  Wankhede Stadium         Mumbai Indians
# 742                   0  Mumbai  Wankhede Stadium         Mumbai Indians
# 743                   0  Mumbai  Wankhede Stadium         Mumbai Indians
# 744                   0  Mumbai  Wankhede Stadium         Mumbai Indians
# 745                   0  Mumbai  Wankhede Stadium         Mumbai Indians
# ...                 ...     ...               ...                    ...
# 142289                0   Delhi  Feroz Shah Kotla  Kolkata Knight Riders
# 142290                0   Delhi  Feroz Shah Kotla  Kolkata Knight Riders
# 142291                0   Delhi  Feroz Shah Kotla  Kolkata Knight Riders
# 142292          B Kumar   Delhi  Feroz Shah Kotla  Kolkata Knight Riders
# 142293                0   Delhi  Feroz Shah Kotla  Kolkata Knight Riders
#
# [90741 rows x 10 columns]

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#         match_id           batting_team           bowling_team  ball  runs  \
# 741            8  Kolkata Knight Riders         Mumbai Indians   0.1     1
# 742            8  Kolkata Knight Riders         Mumbai Indians   0.2     1
# 743            8  Kolkata Knight Riders         Mumbai Indians   0.3     1
# 744            8  Kolkata Knight Riders         Mumbai Indians   0.4     0
# 745            8  Kolkata Knight Riders         Mumbai Indians   0.5     1
# ...          ...                    ...                    ...   ...   ...
# 142289      1168    Sunrisers Hyderabad  Kolkata Knight Riders  19.2     0
# 142290      1168    Sunrisers Hyderabad  Kolkata Knight Riders  19.3     6
# 142291      1168    Sunrisers Hyderabad  Kolkata Knight Riders  19.4     1
# 142292      1168    Sunrisers Hyderabad  Kolkata Knight Riders  19.5     0
# 142293      1168    Sunrisers Hyderabad  Kolkata Knight Riders  19.6     1
#
#        player_dismissed    city             venue
# 741                   0  Mumbai  Wankhede Stadium
# 742                   0  Mumbai  Wankhede Stadium
# 743                   0  Mumbai  Wankhede Stadium
# 744                   0  Mumbai  Wankhede Stadium
# 745                   0  Mumbai  Wankhede Stadium
# ...                 ...     ...               ...
# 142289                0   Delhi  Feroz Shah Kotla
# 142290                0   Delhi  Feroz Shah Kotla
# 142291                0   Delhi  Feroz Shah Kotla
# 142292          B Kumar   Delhi  Feroz Shah Kotla
# 142293                0   Delhi  Feroz Shah Kotla
#
# [90741 rows x 8 columns]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))
